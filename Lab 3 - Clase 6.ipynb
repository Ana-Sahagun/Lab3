# %%
import pandas as pd

# %%
pd1=pd.read_excel(r"C:\Users\anasa\Downloads\marketing_customer_analysis.xlsx")

# %%
pd1.head()
# Out:
#    Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0           0  DK49336     Arizona              4809.216960       No
# 1           1  KX64629  California              2228.525238       No
# 2           2  LZ68649  Washington             14947.917300       No
# 3           3  XL78013      Oregon             22332.439460      Yes
# 4           4  QA50777      Oregon              9025.067525       No
#
#    Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# 0     Basic   College        2011-02-18         Employed      M  ...
# 1     Basic   College        2011-01-18       Unemployed      F  ...
# 2     Basic  Bachelor        2011-02-10         Employed      M  ...
# 3  Extended   College        2011-01-11         Employed      M  ...
# 4   Premium  Bachelor        2011-01-17    Medical Leave      F  ...
#
#    Number of Open Complaints Number of Policies     Policy Type        Policy  \
# ...

# %%
pd1.shape
# Out:
# (10910, 26)

# %%
columnas=list(pd1.columns)

# %%
columnas
# Out:
# ['Unnamed: 0',
#  'Customer',
#  'State',
#  'Customer Lifetime Value',
#  'Response',
#  'Coverage',
#  'Education',
#  'Effective To Date',
#  'EmploymentStatus',
#  'Gender',
#  'Income',
#  'Location Code',
#  'Marital Status',
#  'Monthly Premium Auto',
#  'Months Since Last Claim',
#  'Months Since Policy Inception',
#  'Number of Open Complaints',
#  'Number of Policies',
#  'Policy Type',
#  'Policy',
#  'Renew Offer Type',
#  'Sales Channel',
#  'Total Claim Amount',
#  'Vehicle Class',
#  'Vehicle Size',
#  'Vehicle Type']

# %%
pd1=pd1.rename(columns={"Unnamed: 0":"Unnamed"})

# %%
pd1
# Out:
#        Unnamed Customer       State  Customer Lifetime Value Response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# ...        ...      ...         ...                      ...      ...
# 10905    10905  FE99816      Nevada             15563.369440       No
# 10906    10906  KX53892      Oregon              5259.444853       No
# 10907    10907  TL39050     Arizona             23893.304100       No
# 10908    10908  WA60547  California             11971.977650       No
# 10909    10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
# Para terminar de arreglar encabezados sustituyo espacios por _
pd1.columns = pd1.columns.str.replace(" ", "_")

# %%
pd1
# Out:
#        Unnamed Customer       State  Customer_Lifetime_Value Response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# ...        ...      ...         ...                      ...      ...
# 10905    10905  FE99816      Nevada             15563.369440       No
# 10906    10906  KX53892      Oregon              5259.444853       No
# 10907    10907  TL39050     Arizona             23893.304100       No
# 10908    10908  WA60547  California             11971.977650       No
# 10909    10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective_To_Date EmploymentStatus Gender  ...  \
# ...

# %%
Categorical_vars=['Unnamed',
 'Customer',
 'State',
 'Response',
 'Coverage',
 'Education',
 'Effective To Date',
 'EmploymentStatus',
 'Gender',
 'Location Code',
 'Marital Status',
 'Policy Type',
 'Policy',
 'Renew Offer Type',
 'Sales Channel',
 'Vehicle Class',
 'Vehicle Size',
 'Vehicle Type']

# %%
Numerical_vars=[
 'Customer Lifetime Value', 'Income', "Monthly_Premium_Auto",'Months Since Last Claim', 'Months Since Policy Inception',
 'Number of Open Complaints',
 'Number of Policies', 'Total Claim Amount',]

# %%
#para hacer check de en q columnas hay na
# pd1.isna().count()-> no sirve xq te cuenta todo los true y false en cambio con el otro metodo te suma los true (1), los false cuentan 0
pd1.isna().sum()
# Out:
# Unnamed                          0
# Customer                         0
# State                            0
# Customer_Lifetime_Value          0
# Response                         0
# Coverage                         0
# Education                        0
# Effective_To_Date                0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location_Code                    0
# Marital_Status                   0
# Monthly_Premium_Auto             0
# Months_Since_Last_Claim          0
# Months_Since_Policy_Inception    0
# Number_of_Open_Complaints        0
# Number_of_Policies               0
# Policy_Type                      0
# Policy                           0
# Renew_Offer_Type                 0
# Sales_Channel                    0
# Total_Claim_Amount               0
# Vehicle_Class                    0
# Vehicle_Size                     0
# Vehicle_Type                     0
# dtype: int64

# %%
#Deal with NaN:
# opcion1: sustituir na por cero: pd1=pd1.fillna(0)
# opcion2: Filtrando para que no me muestre las filas con na:
# pd1[pd1["Number_of_Open_Complaints"].notna()]
pd1=pd1.fillna(0)

# %%
pd1
# Out:
#        Unnamed Customer       State  Customer_Lifetime_Value Response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# ...        ...      ...         ...                      ...      ...
# 10905    10905  FE99816      Nevada             15563.369440       No
# 10906    10906  KX53892      Oregon              5259.444853       No
# 10907    10907  TL39050     Arizona             23893.304100       No
# 10908    10908  WA60547  California             11971.977650       No
# 10909    10909  IV32877           0              6857.519928        0
#
#        Coverage Education Effective_To_Date EmploymentStatus Gender  ...  \
# ...

# %%
# Extraer el month en una nueva columna: df['Fecha'] = pd.to_datetime(df['Fecha'])

# %%
from datetime import datetime

# %%
pd1['Month'] = pd1['Effective_To_Date'].dt.month

# %%
#para sacar los datos del Q1, primero voy a ver que solo tengo datos de 1 año porque sino deberia filtrar tb x año
pd1['Year'] = pd1['Effective_To_Date'].dt.year

# %%
pd2=pd1[pd1["Year"]!=2011]

# %%
#Una vez checkeado eso, ya podemos 
pd2
# Out:
# Empty DataFrame
# Columns: [Unnamed, Customer, State, Customer_Lifetime_Value, Response, Coverage, Education, Effective_To_Date, EmploymentStatus, Gender, Income, Location_Code, Marital_Status, Monthly_Premium_Auto, Months_Since_Last_Claim, Months_Since_Policy_Inception, Number_of_Open_Complaints, Number_of_Policies, Policy_Type, Policy, Renew_Offer_Type, Sales_Channel, Total_Claim_Amount, Vehicle_Class, Vehicle_Size, Vehicle_Type, Month, Year]
# Index: []
#
# [0 rows x 28 columns]

# %%
#ahora ya si sabesmos que no habiendo mas años, podemos filtrar por Q1
# ¿? crfedo que todos son de enero y febrero...
pd1=pd1[pd1["Month"]<=3]

# %%
pd1
# Out:
#        Unnamed Customer       State  Customer_Lifetime_Value Response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# ...        ...      ...         ...                      ...      ...
# 10905    10905  FE99816      Nevada             15563.369440       No
# 10906    10906  KX53892      Oregon              5259.444853       No
# 10907    10907  TL39050     Arizona             23893.304100       No
# 10908    10908  WA60547  California             11971.977650       No
# 10909    10909  IV32877           0              6857.519928        0
#
#        Coverage Education Effective_To_Date EmploymentStatus Gender  ...  \
# ...

# %%
# all into a function:
def analisis_consumidor(path):
    pd1=pd.read_excel(path)
    forma=pd1.shape
    columnas=list(pd1.columns)
    pd1=pd1.rename(columns={"Unnamed: 0":"Unnamed"})
    pd1.columns = pd1.columns.str.replace(" ", "_")
    return pd1, forma

# %%
df1, froma= analisis_consumidor(r"C:\Users\anasa\Downloads\marketing_customer_analysis.xlsx")

# %%
df1
# Out:
#        Unnamed Customer       State  Customer_Lifetime_Value Response  \
# 0            0  DK49336     Arizona              4809.216960       No
# 1            1  KX64629  California              2228.525238       No
# 2            2  LZ68649  Washington             14947.917300       No
# 3            3  XL78013      Oregon             22332.439460      Yes
# 4            4  QA50777      Oregon              9025.067525       No
# ...        ...      ...         ...                      ...      ...
# 10905    10905  FE99816      Nevada             15563.369440       No
# 10906    10906  KX53892      Oregon              5259.444853       No
# 10907    10907  TL39050     Arizona             23893.304100       No
# 10908    10908  WA60547  California             11971.977650       No
# 10909    10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective_To_Date EmploymentStatus Gender  ...  \
# ...

# %%
froma
# Out:
# (10910, 26)

# %%
# Processing Data
    # X-y split.
    # Normalize (numerical)
